# %%
import numpy as np
import matplotlib.pyplot as plt
import pywt
from scipy.fft import fft, fftfreq, fftshift
from scipy import signal
from sklearn.preprocessing import StandardScaler
import seaborn as sns
from sklearn.metrics import f1_score,confusion_matrix,cohen_kappa_score

# %%
true=np.load("./signal/labels-4.npy")
pred=np.load("./output.npy")
plt.figure(figsize=(18,7))
plt.subplot(211)
plt.plot(true[:976])
plt.title("True Sleep Stage")
plt.subplot(212)
plt.plot(pred[:976])
plt.title("Predict Sleep Stage")
# Out:
# Text(0.5, 1.0, 'Predict Sleep Stage')
